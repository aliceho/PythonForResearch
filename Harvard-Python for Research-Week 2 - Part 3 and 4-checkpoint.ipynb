# %% [markdown]
# # Introduction to Matplotlib and PyPlot:
#
# 1. Matplotlib is a Python plotting library that produces publication-quality figures.
# 2. Pyplot is a collection of functions that make matplotlib work like Matlab. Pyplot is especially useful for interactive work, for example, when you'd like to explore a dataset or visually examine your simulation results.
# 3. Pyplot provides a state machine interface to matplotlib library. You can loosely think of it as a process where you create figures one at a time, and all commands affect the current figure and the current plot.
# 4. To import Pyplot we will use **import matplotlib.pyplot as plt**.
# 5. **plot()**: can be used to plot lines and markers. The **simplest version of plot has just one argument,** and it specifies the y-axis values that are to be plotted. In this case, when you provide just one argument, the plot function, **each y-axis value will be plotted against its corresponding index value on the x-axis.**
# 6. We can also give **the plot function two arguments,** in which case the **first argument specifies the x-coordinates of the points, and the second argument the y-coordinates of the points.**
# 7. We can also provide a **third argument to the plot function**, which is **a format string that specifies color, marker, and line type.**
# 8. **Keyword Argument**: It is an argument which is supplied to the function by explicitly naming each parameter and specifying its value.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0,1,4,9,16])

# %%
plt.plot([0,1,4,9,16]);

# %%
x = np.linspace(0,10,20)
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y = x**2.0
y
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
plt.plot(x,y)

# %%
x = np.linspace(0,10,20)
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y1 = x**2.0
y1
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
y2 = x**1.5
y2
# Out:
# array([ 0.        ,  0.38182961,  1.07997721,  1.98404483,  3.05463684,
#         4.26898477,  5.61172621,  7.07158325,  8.6398177 , 10.30939934,
#        12.07451231, 13.93024088, 15.87235863, 17.89718087, 20.00145789,
#        22.18229554, 24.43709474, 26.76350449, 29.15938474, 31.6227766 ])

# %%
plt.plot(x, y1, "bo-")

# %%
plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8);

# %%
plt.plot([0,1,2],[0,1,4],"rd-")

# %% [markdown]
# # Customizing your Plots:
#
# 1. There are a few important elements that can be easily added to plots.
# 2. **lengend()**: Matplotlib has native support for legends. Legends can be placed in various positions: A legend can be placed inside or outside the chart and the position can be moved. The legend() method adds the legend to the plot. To place the legend inside, simply call legend().
# 3. **axis()**: use to adjust the axes.
# 4. **xlabel()**: sets the name of x-axis.
# 5. **ylabel()**: sets the name of y-axis.
# 6. **savefig()**: we can save a figure using savefig. In that case, the file format extension specifies the format of the file, such as pdf or png. Syntax : **savefig(fname, dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)**

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.50
plt.plot(x,y1,"bo-", linewidth = 2, markersize= 8)
plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8)

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.50
plt.plot(x,y1,"bo-", linewidth = 2, markersize= 8)
plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
y1 = x**2.0
y2 = x**1.50
plt.plot(x,y1,"bo-", linewidth = 2, markersize= 8)
plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8)
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])  #[xmin,xmax,ymin, ymax]
# Out:
# [-0.5, 10.5, -5, 105]

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.50
z1=plt.plot(x,y1,"bo-", linewidth = 2, markersize= 8, label ="First")
z2=plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8, label = "Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])  #[xmin,xmax,ymin, ymax]
plt.legend(loc="upper center")

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.50
z1=plt.plot(x,y1,"bo-", linewidth = 2, markersize= 8, label ="First")
z2=plt.plot(x,y2,"gs-", linewidth = 2, markersize= 8, label = "Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])  #[xmin,xmax,ymin, ymax]
plt.legend(loc="upper center")
plt.savefig("myplotfirst.pdf")

# %% [markdown]
# # Plotting Using Logarithmic Axes:
#
# 1. In some plots, it's helpful to have one or both axes be logarithmic. This means that for any given point to be plotted, its x or y-coordinate, or both, are transformed using the log function. So what ends up being plotted on the x-axes is not the original x-coordinate, but instead the value of log x
# 2. The logarithm is taken by default in base 10. But the base can be specified to be something else as needed.
# 3. **semilogx()** plots the x-axes on a log scale and the y in the original scale.
# 4. **semilogy()** plots the y-axes on the log scale and the x in the original scale.
# 5. **loglog()** plots both x and y on logarithmic scales.
# 6. There are two main reasons to use logarithmic scales in charts and graphs:
#     - The first is **to respond to skewness towards large values**; i.e., cases in which one or a few points are much larger than the bulk of the data.
#     - The second is **to show percent change or multiplicative factors.**

# %%
x = np.linspace(0,10,20)
y1 = x**2.0
y2 = x**1.50
z1=plt.loglog(x,y1,"bo-", linewidth = 2, markersize= 8, label ="First")
z2=plt.loglog(x,y2,"gs-", linewidth = 2, markersize= 8, label = "Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc="upper center")

# %%
x = np.logspace(-1,1,40)
y1 = x**2.0
y2 = x**1.50
z1=plt.loglog(x,y1,"bo-", linewidth = 2, markersize= 8, label ="First")
z2=plt.loglog(x,y2,"gs-", linewidth = 2, markersize= 8, label = "Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc="upper center")

# %%
x = np.logspace(0,1,10)
y = x**2
plt.loglog(x,y,"bo-")

# %% [markdown]
# # Generating Histograms:
#
# 1. A histogram is a great tool for quickly assessing a probability distribution that is intuitively understood by almost any audience.
# 2. The bins, range, weights, and density are some of the few parameters of the hist():
#     - **x**: Input values, this takes either a single array or a sequence of arrays which are not required to be of the same length.
#     - **bins**: If bins is an integer, it defines the number of equal-width bins in the range. If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge of the last bin; in this case, bins may be unequally spaced. All but the last (righthand-most) bin is half-open.
#     - **range**: The lower and upper range of the bins. Lower and upper outliers are ignored. If not provided, range is (x.min(), x.max()). Range has no effect if bins is a sequence. If bins is a sequence or range is specified, autoscaling is based on the specified bin range instead of the range of x. Default is None.
#     - **density**: If True, the first element of the return tuple will be the counts normalized to form a probability density, i.e., the area (or integral) under the histogram will sum to 1. This is achieved by dividing the count by the number of observations times the bin width and not dividing by the total number of observations. If stacked is also True, the sum of the histograms is normalized to 1. Default is False.
#     - **weights**: An array of weights, of the same shape as x. Each value in x only contributes its associated weight towards the bin count (instead of 1). If normed or density is True, the weights are normalized, so that the integral of the density over the range remains 1. Default is None.
#     - **cumulative**: If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values. The last bin gives the total number of datapoints. If density is also True then the histogram is normalized such that the last bin equals 1. If cumulative is a number less than 0 (e.g., -1), the direction of accumulation is reversed. In this case, if density is also True, then the histogram is normalized such that the first bin equals 1.
#     - **histtype**: The type of histogram to draw.'bar' is a traditional bar-type histogram. If multiple data are given the bars are arranged side by side.'barstacked' is a bar-type histogram where multiple data are stacked on top of each other. 'step' generates a lineplot that is by default unfilled. 'stepfilled' generates a lineplot that is by default filled. Default is 'bar'
# 3. By default, hist uses 10 evenly spaced bins and it tries to optimize both bin width and bin locations. But sometimes you really want to be able to specify the bins yourself.
# 4. **Gamma Distribution**: It is a continuous probability density function that starts at 0 and goes all the way to positive infinity.
# 5. **subplot()**: It enables us to have several subplots within each figure. This upload function takes in three arguments where the first two specify the number of rows and the number of columns in the subplot, and the third argument gives the plot number.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.random.normal(size=1000)
plt.hist(x)
# Out:
# (array([  4.,  14.,  65., 166., 267., 260., 137.,  70.,  13.,   4.]),
#  array([-3.32101288, -2.63621854, -1.95142421, -1.26662987, -0.58183554,
#          0.1029588 ,  0.78775313,  1.47254747,  2.1573418 ,  2.84213614,
#          3.52693047]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.00584117, 0.02044409, 0.09491901, 0.24240855, 0.38989809,
#         0.37967604, 0.20006007, 0.10222047, 0.0189838 , 0.00584117]),
#  array([-3.32101288, -2.63621854, -1.95142421, -1.26662987, -0.58183554,
#          0.1029588 ,  0.78775313,  1.47254747,  2.1573418 ,  2.84213614,
#          3.52693047]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, density=True, bins=np.linspace(-5,5,21));

# %%
x = np.random.gamma(2,3,100000)
plt.hist(x)
# Out:
# (array([4.1008e+04, 3.6060e+04, 1.5224e+04, 5.3920e+03, 1.5580e+03,
#         5.3800e+02, 1.6500e+02, 3.8000e+01, 1.1000e+01, 6.0000e+00]),
#  array([1.35217451e-02, 4.22883770e+00, 8.44415366e+00, 1.26594696e+01,
#         1.68747856e+01, 2.10901015e+01, 2.53054175e+01, 2.95207335e+01,
#         3.37360494e+01, 3.79513654e+01, 4.21666813e+01]),
#  <a list of 10 Patch objects>)

# %%
plt.figure()
plt.subplot(221)
plt.hist(x, bins=30);
plt.subplot(222)
plt.hist(x, bins=30, density=True);
plt.subplot(223)
plt.hist(x, bins=30, cumulative=30);
plt.subplot(224)
plt.hist(x, bins=30, density=True, cumulative=True, histtype= "step");

# %% [markdown]
# # Simulating Randomness:
#
# 1. Many processes in nature involve randomness in one form or another. Whether we investigate the motions of microscopic molecules or study the popularity of electoral candidates, we see randomness, or at least apparent randomness, almost everywhere.
# 2. We often use randomness to model those parts of a process that we can explain in relatively simple terms, and we assume, true or not, that the rest is noise.
# 3. We use **random.choice** to simulate random processes such as coin flips or the roll of a die.

# %%
import random

# %%
random.choice(["Head","Tail"])
# Out:
# 'Tail'

# %%
random.choice(["Head","Tail"])
# Out:
# 'Head'

# %%
random.choice(["Head","Tail"])
# Out:
# 'Head'

# %%
random.choice(["Head","Tail"])
# Out:
# 'Head'

# %%
random.choice(["Head","Tail"])
# Out:
# 'Tail'

# %%
random.choice([0,1])
# Out:
# 1

# %%
random.choice([0,1])
# Out:
# 0

# %%
random.choice([0,1])
# Out:
# 1

# %%
random.choice([1,2,3,4,5,6])
# Out:
# 4

# %%
random.choice([1,2,3,4,5,6])
# Out:
# 2

# %%
random.choice([1,2,3,4,5,6])
# Out:
# 3

# %%
random.choice([1,2,3,4,5,6])
# Out:
# 3

# %%
random.choice(range(1,7))
# Out:
# 6

# %%
random.choice([range(1,7), range(1,9), range(1,11)])
# Out:
# range(1, 11)

# %%
random.choice([range(1,7), range(1,9), range(1,11)])
# Out:
# range(1, 9)

# %%
random.choice(random.choice([range(1,7), range(1,9), range(1,11)]))
# Out:
# 3

# %%
random.choice(random.choice([range(1,7), range(1,9), range(1,11)]))
# Out:
# 5

# %%
random.choice(random.choice([range(1,7), range(1,9), range(1,11)]))
# Out:
# 4

# %%
random.choice(list([1,2,3,4]))
# Out:
# 3

# %%
sum(random.choice(range(10)) for i in range(10)) #lines of code takes the sum of 10 random integers between 0 and 9
# Out:
# 47

# %% [markdown]
# # Examples Involving Randomness:

# %%
import random

# %%
rolls =[]

# %%
for i in range(100):
    rolls.append(random.choice(range(1,7)))

# %%
len(rolls)
# Out:
# 100

# %%
plt.hist(rolls, bins=np.linspace(0.5,6.5,7));

# %%
lst =[]
for i in range(10000):
    lst.append(random.choice(range(1,7)))
plt.hist(lst, bins=np.linspace(0.5,6.5,7));

# %%
l =[]
for i in range(100000):
    l.append(random.choice(range(1,7)))
plt.hist(l, bins=np.linspace(0.5,6.5,7));

# %%
# rolling the dice more than 1 time

ys = []
for i in range(10):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
    
len(ys)
# Out:
# 10

# %%
ys
# Out:
# [42, 29, 36, 41, 24, 23, 29, 31, 36, 30]

# %%
plt.hist(ys);

# %%
ys = []
for i in range(100):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
    
len(ys)
# Out:
# 100

# %%
plt.hist(ys);

# %%
ys = []
for i in range(1000):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
    
len(ys)
# Out:
# 1000

# %%
plt.hist(ys);

# %%
ys = []
for i in range(100000):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
    
len(ys)
# Out:
# 100000

# %%
plt.hist(ys);

# %%
ys = []
for i in range(1000000):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
    
len(ys)
# Out:
# 1000000

# %%
plt.hist(ys);

# %%
random.choice(list((1,2,3,4)))
# Out:
# 4

# %% [markdown]
# # Using the NumPy Random Module:
#
# 1. NumPy makes it possible to generate all kinds of random variables.
# 2. The reason for using NumPy to deal with random variables is because it has a broad range of different kinds of random variables and it's also very fast.
# 3. **numpy.random.random()** :Return random floats in the interval 0 and 1. Results are from the “continuous uniform” distribution over the stated interval.
# 4. **numpy.random.normal()** : Draw random samples from a normal (Gaussian) distribution. Syntax: ***numpy.random.normal(loc=0.0, scale=1.0, size=None)***.
# 5. **numpy.random.randint()**: Return random integers from low (inclusive) to high (exclusive). Syntax: ***numpy.random.randint(low, high=None, size=None, dtype='l')***
# 6. **numpy.sum()**: Sum of array elements over a given axis. Syntax: ***numpy.sum(a, axis=None)***
# 7.  Using NumPy can result in code that runs over 10 times faster than standard Python code.

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.36895506720972826

# %%
np.random.random()
# Out:
# 0.9882969311117036

# %%
np.random.random(5)
# Out:
# array([0.66630665, 0.14893593, 0.04929739, 0.07001417, 0.43353634])

# %%
np.random.random((5,3))
# Out:
# array([[0.23593941, 0.22938433, 0.92589072],
#        [0.4803718 , 0.05588206, 0.33148807],
#        [0.65720543, 0.9784314 , 0.82323125],
#        [0.02232608, 0.22320342, 0.46762699],
#        [0.70993336, 0.04588705, 0.86591533]])

# %%
np.random.normal(0,1)
# Out:
# -1.0752102988921504

# %%
np.random.normal(0,1,5)
# Out:
# array([-0.64961473, -1.26966541,  1.49840212, -0.28631412,  1.34889317])

# %%
np.random.normal(0,1,(5,2))
# Out:
# array([[-0.70662942,  1.11395965],
#        [-0.01734835, -0.29593904],
#        [-0.5344575 ,  0.78397936],
#        [-0.54220806,  0.28431802],
#        [ 1.46223606, -1.58444087]])

# %%
x = np.random.randint(1,7, (10,3))

# %%
x
# Out:
# array([[6, 1, 3],
#        [3, 5, 2],
#        [4, 3, 6],
#        [1, 2, 5],
#        [1, 1, 2],
#        [3, 4, 3],
#        [4, 2, 5],
#        [1, 4, 2],
#        [5, 2, 6],
#        [2, 6, 1]])

# %%
x.shape
# Out:
# (10, 3)

# %%
np.sum(x)
# Out:
# 95

# %%
np.sum(x, axis=0)
# Out:
# array([30, 30, 35])

# %%
np.sum(x, axis=1)
# Out:
# array([10, 10, 13,  8,  4, 10, 11,  7, 13,  9])

# %%
x = np.random.randint(1,7,(100,10))
y = np.sum(x, axis=1)
plt.hist(y);

# %%
x = np.random.randint(1,7,(1000,10))
y = np.sum(x, axis=1)
plt.hist(y);

# %%
x = np.random.randint(1,7,(10000,10))
y = np.sum(x, axis=1)
plt.hist(y);

# %%
x = np.random.randint(1,7,(100000,10))
y = np.sum(x, axis=1)
plt.hist(y);

# %%
x = np.random.randint(1,7,(1000000,10))
y = np.sum(x, axis=1)
plt.hist(y);

# %%
np.random.random((5,2,3))
# Out:
# array([[[0.61679391, 0.88490376, 0.78783665],
#         [0.19439864, 0.68774501, 0.8481425 ]],
#
#        [[0.64811301, 0.53279943, 0.77056889],
#         [0.04979329, 0.75362182, 0.61181935]],
#
#        [[0.10540801, 0.52475901, 0.66381807],
#         [0.59549935, 0.87212642, 0.17875161]],
#
#        [[0.0251614 , 0.19178497, 0.7327092 ],
#         [0.62002531, 0.7765115 , 0.38125206]],
#
#        [[0.66436262, 0.78182854, 0.44592595],
#         [0.97693228, 0.81248873, 0.64155612]]])

# %%
np.random.normal(1,2,3)
# Out:
# array([1.00215727, 3.2609977 , 2.12754375])

# %%
np.random.randint(1,5,(2,3))
# Out:
# array([[3, 4, 1],
#        [2, 3, 2]])

# %%
np.sum(np.random.randint(1,7,(100,10)), axis=0)
# Out:
# array([338, 329, 348, 366, 371, 344, 347, 348, 340, 314])

# %% [markdown]
# # Measuring Time:
#
# 1. It is often helpful to be able to measure how long a segment of code takes to run. One reason for wanting to know might be that you have two or more ways of coding up the same task and you'd like to know which one is faster. Another reason might be that you have a large dataset and you'd like to have a sense ahead of time how long it might take to run your code.
# 2. A simple way to measure time in Python is to use the time module.
# 3. One of the most useful functions in the time module is the time.time(). That gives us the current time.

# %%
import time

# %%
start_time = time.time()
start_time
# Out:
# 1587487322.2503598

# %%
end_time = time.time()
end_time
# Out:
# 1587487322.4724338

# %%
end_time - start_time
# Out:
# 0.22207403182983398

# %%
start_time = time.time()
ys = []
for i in range(10000):
    y= 0
    for z in range(10):
        x = random.choice([1,2,3,4,5,6])
        y = y+x
    ys.append(y)
end_time = time.time()
print(end_time - start_time)
# Out:
# 0.18450498580932617

# %%
start_time = time.time()
x = np.random.randint(1,7,(100000,10))
y = np.sum(x, axis=1)
end_time = time.time()
print(end_time - start_time)
# Out:
# 0.0240023136138916

# %% [markdown]
# # Random Walks:
#
# 1. Random walks have many uses. They can be used to model random movements of molecules, but they can also be used to model spatial trajectories of people, the kind we might be able to measure using GPS or similar technologies.
# 2. There are many different kinds of random walks, and properties of random walks are central to many areas in physics and mathematics.
# 3. **numpy.cumsum()**: Return the cumulative sum of the elements along a given axis. Syntax: ***numpy.cumsum(a, axis=None, dtype=None, out=None)***
# 4. **numpy.contenate()**: Join a sequence of arrays along an existing axis.. Syntax: ***numpy.concatenate((a1, a2, ...), axis=0, out=None)***

# %%
delta_x = np.random.normal(0,1,(2,5))

# %%
plt.plot(delta_x[0], delta_x[1],"go-");

# %%
x = np.cumsum(delta_x, axis =1)

# %%
x
# Out:
# array([[ 0.9918748 , -0.10480387, -0.6997234 , -1.14083827,  0.47282601],
#        [ 0.37368039,  0.88380302,  1.97523862,  4.52716087,  5.7864604 ]])

# %%
delta_x
# Out:
# array([[ 0.9918748 , -1.09667867, -0.59491953, -0.44111487,  1.61366428],
#        [ 0.37368039,  0.51012263,  1.0914356 ,  2.55192225,  1.25929953]])

# %%
plt.plot(x[0],x[1],"ro-");

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.normal(0,1,(2,5))
x = np.concatenate((x_0, np.cumsum(delta_x, axis =1)), axis=1)
plt.plot(x[0],x[1],"ro-");

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.normal(0,1,(2,100))
x = np.concatenate((x_0, np.cumsum(delta_x, axis =1)), axis=1)
plt.plot(x[0],x[1],"ro-");

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.normal(0,1,(2,1000))
x = np.concatenate((x_0, np.cumsum(delta_x, axis =1)), axis=1)
plt.plot(x[0],x[1],"ro-");

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.normal(0,1,(2,100000))
x = np.concatenate((x_0, np.cumsum(delta_x, axis =1)), axis=1)
plt.plot(x[0],x[1],"ro-");
